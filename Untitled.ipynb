# %% [markdown]
# ## Sarah's stupid notes on crypto that no one cares about except NERDS
# ### Hypothesis: Crypto follows graph theory.

# %%
from IPython import display
display.Image("https://media.giphy.com/media/cilShwsfQpfs9yrezF/giphy.gif")

# %% [markdown]
# Okay so hear me out:
# * Crypto coins achieve worth by thier popularity in trading. A coin that isn't popular or exists on an unpopular blockchain isn't worth as much as the more popular coins.
# * The market is volitile, speculative, and largely inhabited by daytraders with little expereince
# * There is no bitcoin insurance or gov backing.
#  * The is not a nation of bitcoin that will go to war with you if you refuse to take thier currency.
#  * It isn't a regulated industry
